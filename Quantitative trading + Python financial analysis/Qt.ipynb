# %%
# Import necessary libraries
import yfinance as yf
import warnings
warnings.filterwarnings('ignore') # Suppress warnings for a cleaner output
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('seaborn')
# List of stock symbols
stocks = ["AAPL", "MSFT", "INTC", "SPY", "^SPX","^VIX" ,"GDX", "GLD", "JPM","JNJ","KO","BA","PG", "GC=F"]

# Fetch data from 2010-01-01 to now and store in a DataFrame
dataframes = []
for stock in stocks:
    df = yf.download(stock, start="2010-01-01")[['Close']]
    df.rename(columns={'Close': stock}, inplace=True)
    dataframes.append(df)

# Merge all dataframes on the 'Date' column
merged_data = pd.concat(dataframes, axis=1)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
merged_data.plot(figsize=(10,12), subplots=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>], dtype=object)

# %%
# Obtain summary statistics, mean, and info for the merged data
merged_data.describe()
# Out:
#               AAPL         MSFT         INTC          SPY         ^SPX  \
# count  3457.000000  3457.000000  3457.000000  3457.000000  3457.000000
# mean     57.588889   110.792447    36.221899   249.650051  2498.897408
# std      53.237629    97.255103    12.633114   104.259011  1046.845456
# min       6.858929    23.010000    17.670000   102.199997  1022.580017
# 25%      19.426071    32.689999    25.010000   163.559998  1633.699951
# 50%      31.837500    60.099998    33.950001   218.860001  2186.159912
# 75%      79.182503   180.529999    47.630001   315.480011  3155.219971
# max     196.449997   359.489990    68.470001   477.709991  4796.560059
#
#               ^VIX          GDX          GLD          JPM          JNJ  \
# count  3457.000000  3457.000000  3457.000000  3457.000000  3457.000000
# mean     18.634920    32.108885   140.514290    85.133805   116.042175
# std       7.152508    12.628838    24.150509    39.026563    37.068759
# ...

# %%
merged_data.mean()
# Out:
# AAPL      57.588889
# MSFT     110.792447
# INTC      36.221899
# SPY      249.650051
# ^SPX    2498.897408
# ^VIX      18.634920
# GDX       32.108885
# GLD      140.514290
# JPM       85.133805
# JNJ      116.042175
# KO        44.779845
# BA       173.683471
# PG        96.289887
# GC=F    1475.293543
# dtype: float64

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3457 entries, 2010-01-04 to 2023-09-27
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    3457 non-null   float64
#  1   MSFT    3457 non-null   float64
#  2   INTC    3457 non-null   float64
#  3   SPY     3457 non-null   float64
#  4   ^SPX    3457 non-null   float64
#  5   ^VIX    3457 non-null   float64
#  6   GDX     3457 non-null   float64
#  7   GLD     3457 non-null   float64
#  8   JPM     3457 non-null   float64
#  9   JNJ     3457 non-null   float64
#  10  KO      3457 non-null   float64
#  11  BA      3457 non-null   float64
#  12  PG      3457 non-null   float64
#  13  GC=F    3454 non-null   float64
# dtypes: float64(14)
# memory usage: 405.1 KB

# %%
import numpy as np

# %%
# Aggregate statistics for merged data
merged_data.aggregate([min,max,np.mean,np.std,np.median])
# Out:
#               AAPL        MSFT       INTC         SPY         ^SPX       ^VIX  \
# min       6.858929   23.010000  17.670000  102.199997  1022.580017   9.140000
# max     196.449997  359.489990  68.470001  477.709991  4796.560059  82.690002
# mean     57.588889  110.792447  36.221899  249.650051  2498.897408  18.634920
# std      53.237629   97.255103  12.633114  104.259011  1046.845456   7.152508
# median   31.837500   60.099998  33.950001  218.860001  2186.159912  16.860001
#
#               GDX         GLD         JPM         JNJ         KO          BA  \
# min     12.470000  100.500000   28.379999   57.020000  25.014999   56.180000
# max     66.629997  193.889999  171.779999  186.009995  66.209999  440.619995
# mean    32.108885  140.514290   85.133805  116.042175  44.779845  173.683471
# std     12.628838   24.150509   39.026563   37.068759   9.427067   94.380933
# median  28.209999  132.210007   76.690002  118.470001  43.360001  145.449997
#
#                 PG         GC=F
# ...

# %%
# Calculate differences between consecutive rows (day-over-day change) and their mean
merged_data.diff().head()
# Out:
#                 AAPL      MSFT      INTC       SPY      ^SPX      ^VIX  \
# Date
# 2010-01-04       NaN       NaN       NaN       NaN       NaN       NaN
# 2010-01-05  0.013215  0.009998 -0.009998  0.299995  3.530029 -0.690001
# 2010-01-06 -0.121786 -0.189999 -0.070002  0.080002  0.619995 -0.190001
# 2010-01-07 -0.013929 -0.320000 -0.199999  0.480003  4.549927 -0.100000
# 2010-01-08  0.050000  0.209999  0.230000  0.379997  3.290039 -0.930000
#
#                  GDX       GLD       JPM       JNJ        KO        BA  \
# Date
# 2010-01-04       NaN       NaN       NaN       NaN       NaN       NaN
# 2010-01-05  0.459999 -0.100006  0.830002 -0.750000 -0.345001  1.840000
# 2010-01-06  1.170002  1.810005  0.239998  0.519997 -0.009998  1.759998
# 2010-01-07 -0.240002 -0.690002  0.870003 -0.459995 -0.070002  2.420002
# 2010-01-08  0.740002  0.550003 -0.110001  0.219997 -0.519999 -0.600002
#
#                   PG       GC=F
# Date
# 2010-01-04       NaN        NaN
# ...

# %%
merged_data.diff().mean()
# Out:
# AAPL    0.046776
# MSFT    0.080766
# INTC    0.003844
# SPY     0.089466
# ^SPX    0.900648
# ^VIX   -0.000156
# GDX    -0.006081
# GLD     0.018507
# JPM     0.029440
# JNJ     0.026565
# KO      0.007888
# BA      0.039569
# PG      0.024832
# GC=F    0.240522
# dtype: float64

# %%
# Calculate percentage changes between consecutive rows and their mean
merged_data.pct_change().head()
# Out:
#                 AAPL      MSFT      INTC       SPY      ^SPX      ^VIX  \
# Date
# 2010-01-04       NaN       NaN       NaN       NaN       NaN       NaN
# 2010-01-05  0.001729  0.000323 -0.000479  0.002647  0.003116 -0.034431
# 2010-01-06 -0.015906 -0.006137 -0.003354  0.000704  0.000546 -0.009819
# 2010-01-07 -0.001849 -0.010400 -0.009615  0.004221  0.004001 -0.005219
# 2010-01-08  0.006648  0.006897  0.011165  0.003328  0.002882 -0.048793
#
#                  GDX       GLD       JPM       JNJ        KO        BA  \
# Date
# 2010-01-04       NaN       NaN       NaN       NaN       NaN       NaN
# 2010-01-05  0.009642 -0.000911  0.019370 -0.011596 -0.012097  0.032752
# 2010-01-06  0.024289  0.016500  0.005494  0.008134 -0.000355  0.030334
# 2010-01-07 -0.004864 -0.006188  0.019809 -0.007137 -0.002485  0.040482
# 2010-01-08  0.015071  0.004963 -0.002456  0.003438 -0.018509 -0.009646
#
#                   PG      GC=F
# Date
# 2010-01-04       NaN       NaN
# ...

# %%
merged_data.pct_change().mean()
# Out:
# AAPL    0.001057
# MSFT    0.000802
# INTC    0.000323
# SPY     0.000442
# ^SPX    0.000444
# ^VIX    0.003099
# GDX     0.000120
# GLD     0.000181
# JPM     0.000510
# JNJ     0.000313
# KO      0.000254
# BA      0.000616
# PG      0.000314
# GC=F    0.000203
# dtype: float64

# %%
merged_data.pct_change().mean().plot()
# Out:
# <Axes: >

# %%
merged_data.pct_change().mean().plot(kind='bar')
# Out:
# <Axes: >

# %%
# Shift data down by one row (useful for calculating returns)
merged_data.shift(1).head()
# Out:
#                 AAPL       MSFT       INTC         SPY         ^SPX  \
# Date
# 2010-01-04       NaN        NaN        NaN         NaN          NaN
# 2010-01-05  7.643214  30.950001  20.879999  113.330002  1132.989990
# 2010-01-06  7.656429  30.959999  20.870001  113.629997  1136.520020
# 2010-01-07  7.534643  30.770000  20.799999  113.709999  1137.140015
# 2010-01-08  7.520714  30.450001  20.600000  114.190002  1141.689941
#
#                  ^VIX        GDX         GLD        JPM        JNJ         KO  \
# Date
# 2010-01-04        NaN        NaN         NaN        NaN        NaN        NaN
# 2010-01-05  20.040001  47.709999  109.800003  42.849998  64.680000  28.520000
# 2010-01-06  19.350000  48.169998  109.699997  43.680000  63.930000  28.174999
# 2010-01-07  19.160000  49.340000  111.510002  43.919998  64.449997  28.165001
# 2010-01-08  19.059999  49.099998  110.820000  44.790001  63.990002  28.094999
#
#                    BA         PG         GC=F
# Date
# ...

# %%
# Calculate log returns for stock data
rets = np.log(merged_data/merged_data.shift(1))

# %%
rets.head().round(3)
# Out:
#              AAPL   MSFT   INTC    SPY   ^SPX   ^VIX    GDX    GLD    JPM  \
# Date
# 2010-01-04    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2010-01-05  0.002  0.000 -0.000  0.003  0.003 -0.035  0.010 -0.001  0.019
# 2010-01-06 -0.016 -0.006 -0.003  0.001  0.001 -0.010  0.024  0.016  0.005
# 2010-01-07 -0.002 -0.010 -0.010  0.004  0.004 -0.005 -0.005 -0.006  0.020
# 2010-01-08  0.007  0.007  0.011  0.003  0.003 -0.050  0.015  0.005 -0.002
#
#               JNJ     KO     BA     PG   GC=F
# Date
# 2010-01-04    NaN    NaN    NaN    NaN    NaN
# 2010-01-05 -0.012 -0.012  0.032  0.000  0.000
# 2010-01-06  0.008 -0.000  0.030 -0.005  0.016
# 2010-01-07 -0.007 -0.002  0.040 -0.005 -0.002
# 2010-01-08  0.003 -0.019 -0.010 -0.001  0.004

# %%
rets.cumsum().apply(np.exp)
# Out:
#                  AAPL       MSFT      INTC       SPY      ^SPX      ^VIX  \
# Date
# 2010-01-04        NaN        NaN       NaN       NaN       NaN       NaN
# 2010-01-05   1.001729   1.000323  0.999521  1.002647  1.003116  0.965569
# 2010-01-06   0.985795   0.994184  0.996169  1.003353  1.003663  0.956088
# 2010-01-07   0.983973   0.983845  0.986590  1.007588  1.007679  0.951098
# 2010-01-08   0.990514   0.990630  0.997605  1.010941  1.010583  0.904691
# ...               ...        ...       ...       ...       ...       ...
# 2023-09-21  22.756132  10.324071  1.659483  3.806494  3.821746  0.875250
# 2023-09-22  22.868650  10.242649  1.636973  3.797935  3.812973  0.858283
# 2023-09-25  23.037429  10.259774  1.642241  3.813906  3.828313  0.843313
# 2023-09-26  22.498389  10.085299  1.620211  3.757875  3.771904  0.945110
# 2023-09-27  22.150367  10.018708  1.636255  3.728271  3.747279  0.973054
#
#                  GDX       GLD       JPM       JNJ        KO        BA  \
# Date
# ...

# %%
# Display and plot cumulative returns
rets.cumsum().apply(np.exp).plot(figsize=(10,6))
# Out:
# <Axes: xlabel='Date'>

# %%
merged_data.resample('1w').last().head()
# Out:
#                 AAPL       MSFT       INTC         SPY         ^SPX  \
# Date
# 2010-01-10  7.570714  30.660000  20.830000  114.570000  1144.979980
# 2010-01-17  7.354643  30.860001  20.799999  113.639999  1136.030029
# 2010-01-24  7.062500  28.959999  19.910000  109.209999  1091.760010
# 2010-01-31  6.859286  28.180000  19.400000  107.389999  1073.869995
# 2010-02-07  6.980714  28.020000  19.469999  106.660004  1066.189941
#
#                  ^VIX        GDX         GLD        JPM        JNJ         KO  \
# Date
# 2010-01-10  18.129999  49.840000  111.370003  44.680000  64.209999  27.575001
# 2010-01-17  17.910000  47.419998  110.860001  43.680000  64.559998  28.145000
# 2010-01-24  27.309999  43.790001  107.169998  39.160000  63.200001  27.120001
# 2010-01-31  24.620001  40.720001  105.959999  38.939999  62.860001  27.125000
# 2010-02-07  26.110001  42.410000  104.680000  38.299999  62.639999  26.545000
#
#                    BA         PG         GC=F
# Date
# ...

# %%
merged_data.resample('1m',label='left').last().head()
# Out:
#                 AAPL       MSFT       INTC         SPY         ^SPX  \
# Date
# 2009-12-31  6.859286  28.180000  19.400000  107.389999  1073.869995
# 2010-01-31  7.307857  28.670000  20.530001  110.739998  1104.489990
# 2010-02-28  8.392857  29.290001  22.290001  117.000000  1169.430054
# 2010-03-31  9.324643  30.540001  22.840000  118.809998  1186.689941
# 2010-04-30  9.174286  25.799999  21.420000  109.370003  1089.410034
#
#                  ^VIX        GDX         GLD        JPM        JNJ         KO  \
# Date
# 2009-12-31  24.620001  40.720001  105.959999  38.939999  62.860001  27.125000
# 2010-01-31  19.500000  43.889999  109.430000  41.970001  63.000000  26.360001
# 2010-02-28  17.590000  44.410000  108.949997  44.750000  65.199997  27.500000
# 2010-03-31  22.049999  50.509998  115.360001  42.580002  64.300003  26.725000
# 2010-04-30  32.070000  49.860001  118.879997  39.580002  58.299999  25.700001
#
#                    BA         PG         GC=F
# Date
# ...

# %%
data =merged_data.dropna()

# %%
windows = 10

# %%
data['AAPL'].rolling(window=windows).min()
# Out:
# Date
# 2010-01-04           NaN
# 2010-01-05           NaN
# 2010-01-06           NaN
# 2010-01-07           NaN
# 2010-01-08           NaN
#                  ...
# 2023-09-21    173.929993
# 2023-09-22    173.929993
# 2023-09-25    173.929993
# 2023-09-26    171.960007
# 2023-09-27    169.300003
# Name: AAPL, Length: 3454, dtype: float64

# %%
data['min'] = data['AAPL'].rolling(window=windows).min()
data['max'] = data['AAPL'].rolling(window=windows).max()
data['mean'] = data['AAPL'].rolling(window=windows).mean()
data['std'] = data['AAPL'].rolling(window=windows).std()

# %%
data.tail()
# Out:
#                   AAPL        MSFT       INTC         SPY         ^SPX  \
# Date
# 2023-09-21  173.929993  319.529999  34.650002  431.390015  4330.000000
# 2023-09-22  174.789993  317.010010  34.180000  430.420013  4320.060059
# 2023-09-25  176.080002  317.540009  34.290001  432.230011  4337.439941
# 2023-09-26  171.960007  312.140015  33.830002  425.880005  4273.529785
# 2023-09-27  169.300003  310.079010  34.165001  422.524994  4245.629883
#
#                  ^VIX        GDX         GLD         JPM         JNJ  \
# Date
# 2023-09-21  17.540001  28.910000  178.050003  147.139999  161.660004
# 2023-09-22  17.200001  28.870001  178.619995  145.729996  160.500000
# 2023-09-25  16.900000  28.510000  177.699997  146.449997  160.259995
# 2023-09-26  18.940001  27.740000  176.279999  144.929993  159.020004
# 2023-09-27  19.500000  26.695000  173.760101  144.595001  156.490005
#
#                    KO          BA          PG         GC=F         min  \
# Date
# ...

# %%
data['a1']=data['AAPL'].rolling(window=30).mean()

# %%
data['a2']=data['AAPL'].rolling(window=250).mean()

# %%
data[['AAPL','a1','a2']].tail()
# Out:
#                   AAPL          a1         a2
# Date
# 2023-09-21  173.929993  179.054333  161.42648
# 2023-09-22  174.789993  178.948333  161.52392
# 2023-09-25  176.080002  178.891334  161.62516
# 2023-09-26  171.960007  178.641334  161.70596
# 2023-09-27  169.300003  178.369667  161.78380

# %%
data[['AAPL','a1','a2']].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# Determine position based on moving averages' cross
data['positions']=np.where(data['a1']>data['a2'],1,-1)

# %%
# Plot AAPL stock, moving averages, and positions
data[['AAPL','a1','a2','positions']].plot(figsize=(10,6))
# Out:
# <Axes: xlabel='Date'>

# %%
# Plot AAPL stock, moving averages, and positions
data[['AAPL','a1','a2','positions']].plot(figsize=(10,6),secondary_y='positions')
# Out:
# <Axes: xlabel='Date'>

# %%
data=data[['^SPX','^VIX']]
data.head()
# Out:
#                    ^SPX       ^VIX
# Date
# 2010-01-04  1132.989990  20.040001
# 2010-01-05  1136.520020  19.350000
# 2010-01-06  1137.140015  19.160000
# 2010-01-07  1141.689941  19.059999
# 2010-01-08  1144.979980  18.129999

# %%
data.plot(subplots=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>], dtype=object)

# %%
data.plot(secondary_y="^VIX")
# Out:
# <Axes: xlabel='Date'>

# %%
data.loc[:'2012-12-31'].plot(secondary_y="^VIX", figsize=(11,6))
# Out:
# <Axes: xlabel='Date'>

# %%
rets = np.log(data/data.shift(1))
rets.head()
# Out:
#                 ^SPX      ^VIX
# Date
# 2010-01-04       NaN       NaN
# 2010-01-05  0.003111 -0.035038
# 2010-01-06  0.000545 -0.009868
# 2010-01-07  0.003993 -0.005233
# 2010-01-08  0.002878 -0.050024

# %%
# Create scatter matrices for returns with histogram and kernel density estimates
pd.plotting.scatter_matrix(rets,alpha=0.2,diagonal='hist',hist_kwds={'bins':50},figsize=(11,6))
# Out:
# array([[<Axes: xlabel='^SPX', ylabel='^SPX'>,
#         <Axes: xlabel='^VIX', ylabel='^SPX'>],
#        [<Axes: xlabel='^SPX', ylabel='^VIX'>,
#         <Axes: xlabel='^VIX', ylabel='^VIX'>]], dtype=object)

# %%
pd.plotting.scatter_matrix(rets,alpha=0.2,diagonal='kde',figsize=(11,6))
# Out:
# array([[<Axes: xlabel='^SPX', ylabel='^SPX'>,
#         <Axes: xlabel='^VIX', ylabel='^SPX'>],
#        [<Axes: xlabel='^SPX', ylabel='^VIX'>,
#         <Axes: xlabel='^VIX', ylabel='^VIX'>]], dtype=object)

# %%
rets.dropna(inplace=True)

# %%
# Fit a linear regression between ^SPX and ^VIX returns
reg = np.polyfit(rets['^SPX'], rets['^VIX'], deg=1)

# %%
rets.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
ax = rets.plot(kind='scatter', x='^SPX',y='^VIX')
ax.plot(rets['^SPX'], np.polyval(reg, rets['^SPX']), 'r')

# %%
rets.corr()
# Out:
#           ^SPX      ^VIX
# ^SPX  1.000000 -0.752357
# ^VIX -0.752357  1.000000

# %%
# Calculate rolling correlation between ^SPX and ^VIX returns
rets['^SPX'].rolling(250).corr(rets['^VIX']).plot(figsize=(10,6))
# Out:
# <Axes: xlabel='Date'>
